# %%
# Import Libraries needed
import pandas as pd
import numpy as np

# %%
# Open csv file and read the first 5 lines

df = pd.read_csv('coffee_survey.csv')

df.head(5)
# Out:
#   Submission ID Respondent ID   Submitted at What is your age?  \
# 0        gMR29l        vDzkBA  9/11/23 20:50   18-24 years old
# 1        BkPN0e        9Z4VME  9/11/23 20:52   25-34 years old
# 2        W5G8jj        XoNLQj   9/12/23 1:33   25-34 years old
# 3        4xWgGr        Gp7gde  9/12/23 12:58   35-44 years old
# 4        QD27Q8        Bp9ogQ  9/12/23 15:24   25-34 years old
#
#   What is your ZIP code?  \
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
#   How many cups of coffee do you typically drink per day?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Where do you typically drink coffee?  \
# 0                                  NaN
# ...

# %%
# Show the number of rows and columns of the Data.

df.shape
# Out:
# (4042, 118)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Columns: 118 entries, Submission ID to Political Affiliation
# dtypes: float64(21), object(97)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#        What kind of flavorings do you add?  \
# count                                  0.0
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#        What kind of flavorings do you add? (Vanilla Syrup)  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
# ...

# %%
# See if there are any duplicates in this data set

df.duplicated(keep='last')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4037    False
# 4038    False
# 4039    False
# 4040    False
# 4041    False
# Length: 4042, dtype: bool

# %%
count_nulls = df.isnull().sum().sort_values(ascending=False)

print(count_nulls)
# Out:
# What other flavoring do you use?                          4042
# What kind of flavorings do you add? (Vanilla Syrup)       4042
# What kind of flavorings do you add?                       4042
# What kind of flavorings do you add? (Other)               4042
# What kind of flavorings do you add? (Peppermint Syrup)    4042
#                                                           ...
# What is your favorite coffee drink?                         62
# What is your age?                                           31
# Respondent ID                                                0
# Submitted at                                                 0
# Submission ID                                                0
# Length: 118, dtype: int64

# %%
# Replace nulls will 'No Answer'

df2 = df.fillna('No Answer')

df2.head(5)
# Out:
#   Submission ID Respondent ID   Submitted at What is your age?  \
# 0        gMR29l        vDzkBA  9/11/23 20:50   18-24 years old
# 1        BkPN0e        9Z4VME  9/11/23 20:52   25-34 years old
# 2        W5G8jj        XoNLQj   9/12/23 1:33   25-34 years old
# 3        4xWgGr        Gp7gde  9/12/23 12:58   35-44 years old
# 4        QD27Q8        Bp9ogQ  9/12/23 15:24   25-34 years old
#
#   What is your ZIP code?  \
# 0              No Answer
# 1              No Answer
# 2              No Answer
# 3              No Answer
# 4              No Answer
#
#   How many cups of coffee do you typically drink per day?  \
# 0                                          No Answer
# 1                                          No Answer
# 2                                          No Answer
# 3                                          No Answer
# 4                                          No Answer
#
#   Where do you typically drink coffee?  \
# 0                            No Answer
# ...

# %%
df2.describe()
# Out:
#        Submission ID Respondent ID    Submitted at What is your age?  \
# count           4042          4042            4042              4042
# unique          4042          3626            1392                 8
# top           gMR29l        7NEEBa  10/21/23 18:10   25-34 years old
# freq               1             5              82              1986
#
#        What is your ZIP code?  \
# count                    4042
# unique                   2180
# top                 No Answer
# freq                       78
#
#        How many cups of coffee do you typically drink per day?  \
# count                                                4042
# unique                                                  7
# top                                                     2
# freq                                                 1663
#
#        Where do you typically drink coffee?  \
# count                                  4042
# unique                                   66
# ...

# %%
count_nulls2 = df2.isnull().sum().sort_values(ascending=False)

print(count_nulls2)
# Out:
# Submission ID                                                    0
# Coffee A - Acidity                                               0
# Coffee D - Acidity                                               0
# Coffee D - Bitterness                                            0
# Coffee C - Notes                                                 0
#                                                                 ..
# Do you usually add anything to your coffee? (No - just black)    0
# Do you usually add anything to your coffee?                      0
# Please specify what your favorite coffee drink is                0
# What is your favorite coffee drink?                              0
# Political Affiliation                                            0
# Length: 118, dtype: int64

# %%
df2 = df2.apply(lambda x: x.str.lower())
df2.head(5)
# Out:
#   Submission ID Respondent ID   Submitted at What is your age?  \
# 0        gmr29l        vdzkba  9/11/23 20:50   18-24 years old
# 1        bkpn0e        9z4vme  9/11/23 20:52   25-34 years old
# 2        w5g8jj        xonlqj   9/12/23 1:33   25-34 years old
# 3        4xwggr        gp7gde  9/12/23 12:58   35-44 years old
# 4        qd27q8        bp9ogq  9/12/23 15:24   25-34 years old
#
#   What is your ZIP code?  \
# 0              no answer
# 1              no answer
# 2              no answer
# 3              no answer
# 4              no answer
#
#   How many cups of coffee do you typically drink per day?  \
# 0                                          no answer
# 1                                          no answer
# 2                                          no answer
# 3                                          no answer
# 4                                          no answer
#
#   Where do you typically drink coffee?  \
# 0                            no answer
# ...

# %%
# Export clean data to new csv for analysis

df2.to_csv('coffee_data_clean.csv', sep=',', )
